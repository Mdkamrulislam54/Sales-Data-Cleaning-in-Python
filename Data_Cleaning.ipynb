# %% [markdown]
# ##Importing the Required Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##Importing the Dataset

# %%
data = pd.read_excel('Sales-Data-Analysis.xlsx')

# %%
data
# Out:
#      Unnamed: 0 Unnamed: 1           Unnamed: 2          Unnamed: 3  \
# 0           NaN   Order ID                 Date             Product
# 1           NaN      10452  2022-11-07 00:00:00               Fries
# 2           NaN      10452  2022-11-07 00:00:00               Fries
# 3           NaN      10453  2022-11-07 00:00:00           Beverages
# 4           NaN      10454  2022-11-07 00:00:00       Sides & Other
# ..          ...        ...                  ...                 ...
# 257         NaN      10709  2022-12-28 00:00:00       Sides & Other
# 258         NaN      10710  2022-12-29 00:00:00             Burgers
# 259         NaN      10711  2022-12-29 00:00:00  Chicken Sandwiches
# 260         NaN      10712  2022-12-29 00:00:00               Fries
# 261         NaN      10713  2022-12-29 00:00:00           Beverages
#
#     Unnamed: 4  Unnamed: 5     Unnamed: 6      Unnamed: 7          Unnamed: 8  \
# 0        Price    Quantity  Purchase Type  Payment Method             Manager
# 1         3.49  573.065903        Online        Gift Card    Tom      Jackson
# 2         3.49  573.065903        Online        Gift Card    Tom      Jackson
# 3         2.95  745.762712        Online        Gift Card         Pablo Perez
# 4         4.99  200.400802      In-store        Gift Card       Joao    Silva
# ..         ...         ...            ...             ...                 ...
# 257       4.99  200.400802    Drive-thru        Gift Card       Walter Muller
# 258      12.99  754.426482    Drive-thru        Gift Card       Walter Muller
# 259       9.95  281.407035    Drive-thru        Gift Card       Walter Muller
# 260       3.49  630.372493    Drive-thru        Gift Card       Walter Muller
# 261       2.95  677.966102    Drive-thru        Gift Card       Walter Muller
#
#     Unnamed: 9
# 0         City
# 1       London
# 2       London
# 3       Madrid
# 4       Lisbon
# ..         ...
# 257     Berlin
# 258     Berlin
# 259     Berlin
# 260     Berlin
# 261     Berlin
#
# [262 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  262 non-null    object
#  2   Unnamed: 2  262 non-null    object
#  3   Unnamed: 3  262 non-null    object
#  4   Unnamed: 4  262 non-null    object
#  5   Unnamed: 5  262 non-null    object
#  6   Unnamed: 6  262 non-null    object
#  7   Unnamed: 7  262 non-null    object
#  8   Unnamed: 8  262 non-null    object
#  9   Unnamed: 9  262 non-null    object
# dtypes: float64(1), object(9)
# memory usage: 20.6+ KB

# %% [markdown]
# ## Drop unwanted Columns

# %%
data.drop(columns="Unnamed: 0",inplace =True)

# %%
data.head()
# Out:
#   Unnamed: 1           Unnamed: 2     Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0   Order ID                 Date        Product      Price    Quantity
# 1      10452  2022-11-07 00:00:00          Fries       3.49  573.065903
# 2      10452  2022-11-07 00:00:00          Fries       3.49  573.065903
# 3      10453  2022-11-07 00:00:00      Beverages       2.95  745.762712
# 4      10454  2022-11-07 00:00:00  Sides & Other       4.99  200.400802
#
#       Unnamed: 6      Unnamed: 7          Unnamed: 8 Unnamed: 9
# 0  Purchase Type  Payment Method             Manager       City
# 1        Online        Gift Card    Tom      Jackson     London
# 2        Online        Gift Card    Tom      Jackson     London
# 3        Online        Gift Card         Pablo Perez     Madrid
# 4      In-store        Gift Card       Joao    Silva     Lisbon

# %% [markdown]
# ## Changing the Column Name

# %%
data.columns
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')

# %%
data.columns= data.loc[0]

# %%
data.head()
# Out:
# 0  Order ID                 Date        Product  Price    Quantity  \
# 0  Order ID                 Date        Product  Price    Quantity
# 1     10452  2022-11-07 00:00:00          Fries   3.49  573.065903
# 2     10452  2022-11-07 00:00:00          Fries   3.49  573.065903
# 3     10453  2022-11-07 00:00:00      Beverages   2.95  745.762712
# 4     10454  2022-11-07 00:00:00  Sides & Other   4.99  200.400802
#
# 0  Purchase Type  Payment Method             Manager    City
# 0  Purchase Type  Payment Method             Manager    City
# 1        Online        Gift Card    Tom      Jackson  London
# 2        Online        Gift Card    Tom      Jackson  London
# 3        Online        Gift Card         Pablo Perez  Madrid
# 4      In-store        Gift Card       Joao    Silva  Lisbon

# %% [markdown]
# ## Drop Unwanted Rows

# %%
data.drop(0,inplace =True)

# %%
data
# Out:
# 0   Order ID                 Date             Product  Price    Quantity  \
# 1      10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 2      10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 3      10453  2022-11-07 00:00:00           Beverages   2.95  745.762712
# 4      10454  2022-11-07 00:00:00       Sides & Other   4.99  200.400802
# 5      10455  2022-11-08 00:00:00             Burgers  12.99  569.668976
# ..       ...                  ...                 ...    ...         ...
# 257    10709  2022-12-28 00:00:00       Sides & Other   4.99  200.400802
# 258    10710  2022-12-29 00:00:00             Burgers  12.99  754.426482
# 259    10711  2022-12-29 00:00:00  Chicken Sandwiches   9.95  281.407035
# 260    10712  2022-12-29 00:00:00               Fries   3.49  630.372493
# 261    10713  2022-12-29 00:00:00           Beverages   2.95  677.966102
#
# 0   Purchase Type Payment Method             Manager    City
# 1         Online       Gift Card    Tom      Jackson  London
# 2         Online       Gift Card    Tom      Jackson  London
# 3         Online       Gift Card         Pablo Perez  Madrid
# 4       In-store       Gift Card       Joao    Silva  Lisbon
# 5       In-store     Credit Card       Walter Muller  Berlin
# ..            ...            ...                 ...     ...
# 257   Drive-thru       Gift Card       Walter Muller  Berlin
# 258   Drive-thru       Gift Card       Walter Muller  Berlin
# 259   Drive-thru       Gift Card       Walter Muller  Berlin
# 260   Drive-thru       Gift Card       Walter Muller  Berlin
# 261   Drive-thru       Gift Card       Walter Muller  Berlin
#
# [261 rows x 9 columns]

# %% [markdown]
# ## Clean Manager Column

# %%
data.Manager.unique()
# Out:
# array(['Tom      Jackson', '       Pablo Perez', 'Joao    Silva',
#        'Walter Muller', 'Remy    Monet', 'Remy Monet',
#        '       Remy Monet', 'Remy     Monet', 'Pablo Perez',
#        'Pablo   Perez', 'Pablo  Perez', 'Pablo    Perez', 'Joao Silva',
#        'Tom Jackson'], dtype=object)

# %%
data.Manager.nunique()
# Out:
# 14

# %%
data["Manager"]=data["Manager"].str.strip().str.replace(r'\s+',' ', regex= True)

# %%
data.head(20)
# Out:
# 0  Order ID                 Date             Product  Price    Quantity  \
# 1     10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 2     10452  2022-11-07 00:00:00               Fries   3.49  573.065903
# 3     10453  2022-11-07 00:00:00           Beverages   2.95  745.762712
# 4     10454  2022-11-07 00:00:00       Sides & Other   4.99  200.400802
# 5     10455  2022-11-08 00:00:00             Burgers  12.99  569.668976
# 6     10456  2022-11-08 00:00:00  Chicken Sandwiches   9.95  201.005025
# 7     10457  2022-11-08 00:00:00               Fries   3.49  573.065903
# 8     10459  2022-11-08 00:00:00       Sides & Other   4.99  200.400802
# 9     10460  2022-11-09 00:00:00             Burgers  12.99  554.272517
# 10    10461  2022-11-09 00:00:00  Chicken Sandwiches   9.95  201.005025
# 11    10462  2022-11-09 00:00:00               Fries   3.49  573.065903
# 12    10463  2022-11-09 00:00:00           Beverages   2.95  677.966102
# 13    10464  2022-11-09 00:00:00       Sides & Other   4.99  200.400802
# 14    10465  2022-11-10 00:00:00             Burgers  12.99  554.272517
# 15    10466  2022-11-10 00:00:00  Chicken Sandwiches   9.95  201.005025
# 16    10467  2022-11-10 00:00:00               Fries   3.49  573.065903
# 17    10467  2022-11-10 00:00:00               Fries   3.49  573.065903
# 18    10468  2022-11-10 00:00:00           Beverages   2.95  677.966102
# 19    10470  2022-11-11 00:00:00             Burgers  12.99  554.272517
# 20    10471  2022-11-11 00:00:00  Chicken Sandwiches   9.95  201.005025
#
# 0  Purchase Type Payment Method        Manager    City
# 1        Online       Gift Card    Tom Jackson  London
# 2        Online       Gift Card    Tom Jackson  London
# 3        Online       Gift Card    Pablo Perez  Madrid
# 4      In-store       Gift Card     Joao Silva  Lisbon
# 5      In-store     Credit Card  Walter Muller  Berlin
# 6      In-store     Credit Card  Walter Muller  Berlin
# 7      In-store     Credit Card     Remy Monet   Paris
# 8      In-store     Credit Card  Walter Muller  Berlin
# 9      In-store     Credit Card     Remy Monet   Paris
# 10     In-store     Credit Card     Remy Monet   Paris
# 11     In-store     Credit Card     Remy Monet   Paris
# 12     In-store     Credit Card     Remy Monet   Paris
# 13     In-store     Credit Card     Remy Monet   Paris
# 14     In-store     Credit Card    Pablo Perez  Madrid
# 15     In-store     Credit Card    Pablo Perez  Madrid
# 16     In-store     Credit Card    Pablo Perez  Madrid
# 17     In-store     Credit Card    Pablo Perez  Madrid
# 18     In-store     Credit Card    Pablo Perez  Madrid
# 19     In-store     Credit Card    Pablo Perez  Madrid
# 20     In-store     Credit Card    Pablo Perez  Madrid

# %%
data["Manager"].nunique()
# Out:
# 5

# %% [markdown]
# ## Remove the Duplicate Records

# %%
data.describe()
# Out:
# /tmp/ipykernel_14095/3175101911.py:1: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   data.describe()
# 0       Order ID                 Date Product   Price    Quantity  \
# count        261                  261     261  261.00  261.000000
# unique       254                   53       5   10.00   29.000000
# top        10452  2022-11-13 00:00:00   Fries    3.49  200.400802
# freq           2                    7      53   52.00   50.000000
#
# 0      Purchase Type Payment Method     Manager    City
# count            261            261         261     261
# unique             3              3           5       5
# top          Online     Credit Card  Joao Silva  Lisbon
# freq             108            126          78      78

# %%
data[data.duplicated()]
# Out:
# 0  Order ID                 Date             Product Price    Quantity  \
# 2     10452  2022-11-07 00:00:00               Fries  3.49  573.065903
# 17    10467  2022-11-10 00:00:00               Fries  3.49  573.065903
# 28    10478  2022-11-12 00:00:00           Beverages  2.95  677.966102
# 87    10536  2022-11-24 00:00:00  Chicken Sandwiches  9.95  201.005025
#
# 0  Purchase Type Payment Method      Manager    City
# 2        Online       Gift Card  Tom Jackson  London
# 17     In-store     Credit Card  Pablo Perez  Madrid
# 28     In-store     Credit Card  Pablo Perez  Madrid
# 87   Drive-thru     Credit Card  Pablo Perez  Madrid

# %%
data.drop_duplicates(inplace=True)

# %%
data.describe()
# Out:
# /tmp/ipykernel_14095/3175101911.py:1: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   data.describe()
# 0       Order ID                 Date  Product   Price    Quantity  \
# count        257                  257      257  257.00  257.000000
# unique       254                   53        5   10.00   29.000000
# top        10484  2022-11-13 00:00:00  Burgers   12.99  200.400802
# freq           2                    7       53   52.00   50.000000
#
# 0      Purchase Type Payment Method     Manager    City
# count            257            257         257     257
# unique             3              3           5       5
# top          Online     Credit Card  Joao Silva  Lisbon
# freq             107            123          78      78

# %%
data[data["Order ID"].duplicated()]
# Out:
# 0  Order ID                 Date        Product   Price    Quantity  \
# 65    10483  2022-11-13 00:00:00      Beverages   33.92  677.966102
# 67    10484  2022-11-13 00:00:00  Sides & Other    4.99  200.400802
# 69    10485  2022-11-14 00:00:00        Burgers  112.99    523.4796
#
# 0  Purchase Type Payment Method     Manager    City
# 65     In-store     Credit Card  Joao Silva  Lisbon
# 67     In-store     Credit Card  Joao Silva  Lisbon
# 69     In-store     Credit Card  Joao Silva  Lisbon

# %% [markdown]
# ## Duplicate by Outliers

# %%
data[data["Order ID"]== 10483]
# Out:
# 0  Order ID                 Date    Product  Price    Quantity Purchase Type  \
# 64    10483  2022-11-13 00:00:00  Beverages   2.95  677.966102     In-store
# 65    10483  2022-11-13 00:00:00  Beverages  33.92  677.966102     In-store
#
# 0  Payment Method     Manager    City
# 64    Credit Card  Joao Silva  Lisbon
# 65    Credit Card  Joao Silva  Lisbon

# %%
data[data["Order ID"]== 10484]
# Out:
# 0  Order ID                 Date        Product  Price    Quantity  \
# 66    10484  2022-11-13 00:00:00  Sides & Other  44.99  200.400802
# 67    10484  2022-11-13 00:00:00  Sides & Other   4.99  200.400802
#
# 0  Purchase Type Payment Method     Manager    City
# 66     In-store     Credit Card  Joao Silva  Lisbon
# 67     In-store     Credit Card  Joao Silva  Lisbon

# %%
data[data["Order ID"]== 10485]
# Out:
# 0  Order ID                 Date  Product   Price  Quantity Purchase Type  \
# 68    10485  2022-11-14 00:00:00  Burgers   12.99  523.4796     In-store
# 69    10485  2022-11-14 00:00:00  Burgers  112.99  523.4796     In-store
#
# 0  Payment Method     Manager    City
# 68    Credit Card  Joao Silva  Lisbon
# 69    Credit Card  Joao Silva  Lisbon

# %%
data.drop([65,66,69], inplace= True)

# %%
data.describe()
# Out:
# /tmp/ipykernel_14095/3175101911.py:1: FutureWarning: The behavior of value_counts with object-dtype is deprecated. In a future version, this will *not* perform dtype inference on the resulting index. To retain the old behavior, use `result.index = result.index.infer_objects()`
#   data.describe()
# 0       Order ID                 Date             Product   Price    Quantity  \
# count        254                  254                 254  254.00  254.000000
# unique       254                   53                   5    7.00   29.000000
# top        10452  2022-11-09 00:00:00  Chicken Sandwiches   12.99  200.400802
# freq           1                    5                  52   52.00   49.000000
#
# 0      Purchase Type Payment Method      Manager    City
# count            254            254          254     254
# unique             3              3            5       5
# top          Online     Credit Card  Tom Jackson  London
# freq             107            120           75      75

# %% [markdown]
# ## Converting the DataTypes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 254 entries, 1 to 261
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    object
#  4   Quantity        254 non-null    object
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: object(9)
# memory usage: 19.8+ KB

# %%
data.Quantity=data.Quantity.astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 254 entries, 1 to 261
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    object
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    object
#  4   Quantity        254 non-null    float64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 19.8+ KB

# %%
data.Quantity=data.Quantity.round()

# %%
data.Quantity
# Out:
# 1      573.0
# 3      746.0
# 4      200.0
# 5      570.0
# 6      201.0
#        ...
# 257    200.0
# 258    754.0
# 259    281.0
# 260    630.0
# 261    678.0
# Name: Quantity, Length: 254, dtype: float64

# %%
data.Quantity=data.Quantity.astype(int)

# %%
data.Quantity
# Out:
# 1      573
# 3      746
# 4      200
# 5      570
# 6      201
#       ...
# 257    200
# 258    754
# 259    281
# 260    630
# 261    678
# Name: Quantity, Length: 254, dtype: int64

# %%
data['Order ID']=data['Order ID'].astype(int)
data['Price']= data['Price'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 254 entries, 1 to 261
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int64
#  1   Date            254 non-null    object
#  2   Product         254 non-null    object
#  3   Price           254 non-null    float64
#  4   Quantity        254 non-null    int64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 19.8+ KB

# %% [markdown]
# ## Convert to Date Format

# %%
data['Date']= pd.to_datetime(data['Date'])

# %%
data['Date']
# Out:
# 1     2022-11-07
# 3     2022-11-07
# 4     2022-11-07
# 5     2022-11-08
# 6     2022-11-08
#          ...
# 257   2022-12-28
# 258   2022-12-29
# 259   2022-12-29
# 260   2022-12-29
# 261   2022-12-29
# Name: Date, Length: 254, dtype: datetime64[ns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 254 entries, 1 to 261
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        254 non-null    int64
#  1   Date            254 non-null    datetime64[ns]
#  2   Product         254 non-null    object
#  3   Price           254 non-null    float64
#  4   Quantity        254 non-null    int64
#  5   Purchase Type   254 non-null    object
#  6   Payment Method  254 non-null    object
#  7   Manager         254 non-null    object
#  8   City            254 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5)
# memory usage: 19.8+ KB

# %%
data
# Out:
# 0    Order ID       Date             Product  Price  Quantity Purchase Type  \
# 1       10452 2022-11-07               Fries   3.49       573       Online
# 3       10453 2022-11-07           Beverages   2.95       746       Online
# 4       10454 2022-11-07       Sides & Other   4.99       200     In-store
# 5       10455 2022-11-08             Burgers  12.99       570     In-store
# 6       10456 2022-11-08  Chicken Sandwiches   9.95       201     In-store
# ..        ...        ...                 ...    ...       ...           ...
# 257     10709 2022-12-28       Sides & Other   4.99       200   Drive-thru
# 258     10710 2022-12-29             Burgers  12.99       754   Drive-thru
# 259     10711 2022-12-29  Chicken Sandwiches   9.95       281   Drive-thru
# 260     10712 2022-12-29               Fries   3.49       630   Drive-thru
# 261     10713 2022-12-29           Beverages   2.95       678   Drive-thru
#
# 0   Payment Method        Manager    City
# 1        Gift Card    Tom Jackson  London
# 3        Gift Card    Pablo Perez  Madrid
# 4        Gift Card     Joao Silva  Lisbon
# 5      Credit Card  Walter Muller  Berlin
# 6      Credit Card  Walter Muller  Berlin
# ..             ...            ...     ...
# 257      Gift Card  Walter Muller  Berlin
# 258      Gift Card  Walter Muller  Berlin
# 259      Gift Card  Walter Muller  Berlin
# 260      Gift Card  Walter Muller  Berlin
# 261      Gift Card  Walter Muller  Berlin
#
# [254 rows x 9 columns]
